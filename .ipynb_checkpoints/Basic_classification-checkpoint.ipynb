# %% [markdown]
# 该项目使用`tf.keras` ，训练一个神经网络来对衣服图片进行分类，所用的数据**Fashion MNIST**内置在tensorflow里

# %%
from __future__ import absolute_import, division, print_function, unicode_literals


import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.1.0

# %%
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# ...
# 4423680/4422102 [==============================] - 2s 0us/step

# %% [markdown]
# 这些图片是28x28的numpy arrays. labels是从0到9的整数，每一个代表一种类型的服装。
# ![](https://i.loli.net/2020/03/09/mnfYgijNueyFkBI.png)
# 服装名字并不包含在数据集内

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
              'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# 这代表训练数据集有60000张图片，每张图片的大小为28x28 pixels.

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %% [markdown]
# 测试数据集有10000张， 规格一致

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
test_labels
# Out:
# array([9, 2, 1, ..., 8, 1, 5], dtype=uint8)

# %% [markdown]
# ## 处理数据
# 初始数据的像素值是0-255

# %%
plt.figure()
plt.imshow(train_images[10])
plt.colorbar()
plt.grid(False)
plt.show()

# %% [markdown]
# 在将数据放入神经网络前将他们的像素值缩放至0-1

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
plt.figure(figsize = (10,10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap = plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# ## 建立模型

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128, activation = 'relu'),
    keras.layers.Dense(10)
])

# %% [markdown]
# 神经网络的第一层，`tf.keras.layers.Flatten`, 将图像从二维数组（28x28）转化成了一维数组（28x28=784）
# 后面两个`tf.keras.layers.Dense`层，是紧密相连的，或完全相连的，第一个`Dense`有128个节点（或者神经元），第二个是一个 10-node-softmax 层，它返回的是一个包含了10种可能性的数组，这些可能性的和为1

# %% [markdown]
# ## 编制模型
#
# - Loss Function
# - Optimizer
# - Metrics

# %%
model.compile(optimizer = 'adam',
             loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
             metrics = ['accuracy'])

# %% [markdown]
# ## 训练模型
#
# ### Feed the model

# %%
model.fit(train_images, train_labels, epochs = 10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 3s 58us/sample - loss: 0.5018 - accuracy: 0.8236
# Epoch 2/10
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.3712 - accuracy: 0.8662
# Epoch 3/10
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.3359 - accuracy: 0.8776
# Epoch 4/10
# 60000/60000 [==============================] - 3s 50us/sample - loss: 0.3125 - accuracy: 0.8864s - loss: 0.3130 - accura
# Epoch 5/10
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.2926 - accuracy: 0.8925
# Epoch 6/10
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.2804 - accuracy: 0.8949
# Epoch 7/10
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.2681 - accuracy: 0.9005
# Epoch 8/10
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.2577 - accuracy: 0.9043s - loss: 0.2567
# Epoch 9/10
# ...

# %% [markdown]
# ### 评估准确性

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose = 2)

print('\ntest accuracy:', test_acc)
# Out:
# 10000/10000 - 0s - loss: 0.3373 - accuracy: 0.8816
#
# test accuracy: 0.8816

# %% [markdown]
# 可以看到测试数据集的准确性略小于训练数据集的准确性，这种差距代表 **过度拟合（overfitting）**

# %% [markdown]
# ### 做预测

# %%
probability_model = tf.keras.Sequential([model, tf.keras.layers.Softmax()])
predictions = probability_model.predict(test_images)

# %%
predictions[0]
# Out:
# array([3.3769856e-10, 1.5734485e-10, 1.1915358e-10, 1.4837681e-09,
#        7.9373136e-10, 1.9737314e-03, 5.3895423e-08, 1.4699679e-02,
#        1.1527037e-07, 9.8332638e-01], dtype=float32)

# %% [markdown]
# 预测是一个10位数组，每个元素可以理解为该图片是相对应的label的可能性，下面可以进行验证

# %%
np.argmax(predictions[1])
# Out:
# 2

# %%
test_labels[0]
# Out:
# 9

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)
  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
i = 0
plt.figure(figsize = (6,3))
plt.subplot(1, 2, 1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1, 2, 2)
plot_value_array(i, predictions[i], test_labels)
plt.show()

# %%
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions[i], test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions[i], test_labels)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 使用训练好的模型

# %%
img = test_images[1]
img.shape
# Out:
# (28, 28)

# %%
img = np.expand_dims(img, 0)
img.shape
# Out:
# (1, 28, 28)

# %%
predictions_single = probability_model.predict(img)
print(predictions_single)
# Out:
# [[5.7602014e-05 2.7941681e-12 9.9674219e-01 1.9446500e-10 2.8498606e-03
#   4.7945135e-16 3.5038672e-04 1.7136049e-15 4.3338482e-11 2.0194678e-14]]

# %%
plot_value_array(1, predictions_single[0], test_labels)
_ = plt.xticks(range(10), class_names, rotation=45)

# %%
np.argmax(predictions_single)
# Out:
# 2
